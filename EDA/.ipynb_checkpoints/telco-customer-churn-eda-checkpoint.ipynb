# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('bmh')
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('training_data.csv')

# %%
data.shape
# Out:
# (21129, 22)

# %%
data.head()
# Out:
#                         _id  customerID  gender  SeniorCitizen Partner  \
# 0  6599938bf01702ec1d7d7f1b  7590-VHVEG  Female              0     Yes
# 1  6599938bf01702ec1d7d7f1c  5575-GNVDE    Male              0      No
# 2  6599938bf01702ec1d7d7f1d  3668-QPYBK    Male              0      No
# 3  6599938bf01702ec1d7d7f1e  7795-CFOCW    Male              0      No
# 4  6599938bf01702ec1d7d7f1f  9237-HQITU  Female              0      No
#
#   Dependents  tenure PhoneService     MultipleLines InternetService  \
# 0         No       1           No  No phone service             DSL
# 1         No      34          Yes                No             DSL
# 2         No       2          Yes                No             DSL
# 3         No      45           No  No phone service             DSL
# 4         No       2          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes
# 3           42.30      1840.75    No
# 4           70.70       151.65   Yes

# %%
data.tail()
# Out:
#                             _id  customerID  gender  SeniorCitizen Partner  \
# 21124  659a172650c982b057e3df3d  6840-RESVB    Male              0     Yes
# 21125  659a172650c982b057e3df3e  2234-XADUH  Female              0     Yes
# 21126  659a172650c982b057e3df3f  4801-JZAZL  Female              0     Yes
# 21127  659a172650c982b057e3df40  8361-LTMKD    Male              1     Yes
# 21128  659a172650c982b057e3df41  3186-AJIEK    Male              0      No
#
#       Dependents  tenure PhoneService     MultipleLines InternetService  \
# 21124        Yes      24          Yes               Yes             DSL
# 21125        Yes      72          Yes               Yes     Fiber optic
# 21126        Yes      11           No  No phone service             DSL
# 21127         No       4          Yes               Yes     Fiber optic
# 21128         No      66          Yes                No     Fiber optic
#
#       OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 21124            Yes           No              Yes         Yes         Yes
# 21125             No          Yes              Yes          No         Yes
# 21126            Yes           No               No          No          No
# 21127             No           No               No          No          No
# 21128            Yes           No              Yes         Yes         Yes
#
#       StreamingMovies        Contract PaperlessBilling  \
# 21124             Yes        One year              Yes
# 21125             Yes        One year              Yes
# 21126              No  Month-to-month              Yes
# 21127              No  Month-to-month              Yes
# 21128             Yes        Two year              Yes
#
#                    PaymentMethod  MonthlyCharges TotalCharges Churn
# 21124               Mailed check           84.80       1990.5    No
# 21125    Credit card (automatic)          103.20       7362.9    No
# 21126           Electronic check           29.60       346.45    No
# 21127               Mailed check           74.40        306.6   Yes
# 21128  Bank transfer (automatic)          105.65       6844.5    No

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21129 entries, 0 to 21128
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               21129 non-null  object
#  1   customerID        21129 non-null  object
#  2   gender            21129 non-null  object
#  3   SeniorCitizen     21129 non-null  object
#  4   Partner           21129 non-null  object
#  5   Dependents        21129 non-null  object
#  6   tenure            21129 non-null  int64
#  7   PhoneService      21129 non-null  object
#  8   MultipleLines     21129 non-null  object
#  9   InternetService   21129 non-null  object
#  10  OnlineSecurity    21129 non-null  object
#  11  OnlineBackup      21129 non-null  object
#  12  DeviceProtection  21129 non-null  object
#  13  TechSupport       21129 non-null  object
#  14  StreamingTV       21129 non-null  object
#  15  StreamingMovies   21129 non-null  object
#  16  Contract          21129 non-null  object
#  17  PaperlessBilling  21129 non-null  object
#  18  PaymentMethod     21129 non-null  object
#  19  MonthlyCharges    21129 non-null  float64
#  20  TotalCharges      21096 non-null  float64
#  21  Churn             21129 non-null  object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 3.5+ MB

# %%
data['SeniorCitizen'] = data["SeniorCitizen"].astype('O')
data['TotalCharges'] = pd.to_numeric(data["TotalCharges"], errors='coerce')

# %%
numerical_columns = data.select_dtypes(include = ['int64', 'float64']).columns.tolist()
print(f"numerical_columns : {numerical_columns}")
# Out:
# numerical_columns : ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
categorical_columns = data.select_dtypes(include = ['O']).columns.tolist()
print(f"categorical_columns : {categorical_columns}")
# Out:
# categorical_columns : ['_id', 'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']
